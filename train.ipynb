# %%
from tensorflow.keras.applications import resnet50
from tensorflow import keras
def create_model(input_shape, weights=None):
    base_model = resnet50.ResNet50(input_shape=input_shape, include_top=False, weights=weights)
    x1 = keras.layers.GlobalAveragePooling2D()(base_model.output)
    x2 = keras.layers.GlobalMaxPooling2D()(base_model.output)
    x = keras.layers.concatenate([x1,x2])
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.7)(x)
    x = keras.layers.Dense(1024, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.7)(x)
    output = keras.layers.Dense(1, activation='sigmoid')(x)
    model = keras.models.Model(inputs=[base_model.input], outputs=[output])
    return model

# %%
import librosa
import numpy as np
from functools import lru_cache
def trim_silence(x, pad=0, db_max=50):
    _, ints = librosa.effects.trim(x, top_db=db_max, frame_length=256, hop_length=64)
    start   = int(max(ints[0]-pad, 0))
    end     = int(min(ints[1]+pad, len(x)))
    return x[start:end]

def process_file(path, chunk=3):
    x, sr = librosa.load(path, sr=None)
    if len(x)/sr < 0.3 or len(x)/sr > 30:
        print(len(x), sr, len(x) / sr, path)
        return None,None
   
    x = trim_silence(x, pad=0.25*sr, db_max=50) 
    x = x[:np.floor(chunk*sr).astype(int)]
    
    #pads to chunk size if smaller
    x_pad = np.zeros(int(sr*chunk))
    x_pad[:min(len(x_pad), len(x))] = x[:min(len(x_pad), len(x))]
    
    hop_length = np.floor(0.010*sr).astype(int) 
    win_length = np.floor(0.020*sr).astype(int) 
    return x_pad, sr, hop_length, win_length

@lru_cache(maxsize=4000)
def get_MFCCS(path, final_dim=(300,200)):
    audio, sr, hop_length, win_length = process_file(path)
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mels=200, n_mfcc=200, n_fft=2048, 
                                hop_length=hop_length)
    mfcc = np.swapaxes(mfcc, 0, 1)
    mfcc = mfcc[:final_dim[0], :final_dim[1]]
    mfcc = np.expand_dims(mfcc, -1)
    return mfcc

# %%
import random
class DataGenerator(keras.utils.Sequence):
    def __init__(self, X, y, batch_size):
        self.X = X
        self.y = y
        self.batch_size = batch_size  
        self.indexes = set(np.arange(len(X)))
        
    def __len__(self):
        return len(self.indexes)

    def __getitem__(self, _):
        indexes = random.sample(self.indexes, self.batch_size)
        X = []
        y = []
        for index in indexes:
            X.append(get_MFCCS(self.X[index]))
            y.append(self.y[index])
        return np.array(X), np.array(y, dtype=int)

# %%
import glob
X1 = glob.glob("audio/with_them/*.wav")
X0 = glob.glob("audio/without_them/*.wav")
X = X1 + X0
y = [1]*len(X1) + [0] * len(X0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.8, random_state=69, stratify=y)

# %%
train_generator = DataGenerator(X_train, y_train, 8)
val_generator = DataGenerator(X_val, y_val, 8)

# %%
model = create_model(input_shape=(300,200,1))
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['acc'])

# %%
history = model.fit(train_generator, steps_per_epoch=30, validation_steps=50, epochs=50, validation_data=val_generator,)
          # callbacks=[keras.callbacks.EarlyStopping(monitor='val_acc', patience=3)])
# Out:
# Epoch 1/50
# 30/30 [==============================] - 17s 252ms/step - loss: 0.6493 - acc: 0.7167 - val_loss: 0.5983 - val_acc: 0.7100
# Epoch 2/50
# 30/30 [==============================] - 6s 201ms/step - loss: 0.4537 - acc: 0.8193 - val_loss: 2.8445 - val_acc: 0.2875
# Epoch 3/50
# 30/30 [==============================] - 5s 154ms/step - loss: 0.3375 - acc: 0.8267 - val_loss: 8.6766 - val_acc: 0.2200
# Epoch 4/50
# 30/30 [==============================] - 4s 139ms/step - loss: 0.1731 - acc: 0.9538 - val_loss: 11.9180 - val_acc: 0.2950
# Epoch 5/50
# 30/30 [==============================] - 4s 123ms/step - loss: 0.1826 - acc: 0.9228 - val_loss: 12.7798 - val_acc: 0.2600
# Epoch 6/50
# 30/30 [==============================] - 4s 124ms/step - loss: 0.3412 - acc: 0.8748 - val_loss: 13.0295 - val_acc: 0.2850
# Epoch 7/50
# 30/30 [==============================] - 3s 113ms/step - loss: 0.0945 - acc: 0.9584 - val_loss: 13.4831 - val_acc: 0.2850
# Epoch 8/50
# 30/30 [==============================] - 8s 281ms/step - loss: 0.1911 - acc: 0.9287 - val_loss: 13.9061 - val_acc: 0.3275
# Epoch 9/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0272 - acc: 0.9919 - val_loss: 14.2150 - val_acc: 0.2900
# Epoch 10/50
# 30/30 [==============================] - 4s 118ms/step - loss: 0.2617 - acc: 0.9162 - val_loss: 13.8772 - val_acc: 0.3325
# Epoch 11/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.1093 - acc: 0.9536 - val_loss: 12.7170 - val_acc: 0.2850
# Epoch 12/50
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0339 - acc: 0.9814 - val_loss: 11.6608 - val_acc: 0.3075
# Epoch 13/50
# 30/30 [==============================] - 9s 291ms/step - loss: 0.0611 - acc: 0.9832 - val_loss: 10.0497 - val_acc: 0.2675
# Epoch 14/50
# 30/30 [==============================] - 6s 193ms/step - loss: 0.0608 - acc: 0.9815 - val_loss: 6.5369 - val_acc: 0.3025
# Epoch 15/50
# 30/30 [==============================] - 6s 204ms/step - loss: 0.0157 - acc: 0.9904 - val_loss: 5.2957 - val_acc: 0.3325
# Epoch 16/50
# 30/30 [==============================] - 5s 166ms/step - loss: 0.2130 - acc: 0.9288 - val_loss: 1.5990 - val_acc: 0.8500
# Epoch 17/50
# 30/30 [==============================] - 5s 152ms/step - loss: 0.0942 - acc: 0.9601 - val_loss: 0.8216 - val_acc: 0.8975
# Epoch 18/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0799 - acc: 0.9748 - val_loss: 0.2415 - val_acc: 0.9575
# Epoch 19/50
# 30/30 [==============================] - 4s 146ms/step - loss: 0.1344 - acc: 0.9431 - val_loss: 0.5889 - val_acc: 0.9225
# Epoch 20/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.1421 - acc: 0.9426 - val_loss: 0.1992 - val_acc: 0.9625
# Epoch 21/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.2489 - acc: 0.8669 - val_loss: 0.9291 - val_acc: 0.9025
# Epoch 22/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0452 - acc: 0.9860 - val_loss: 0.2358 - val_acc: 0.9775
# Epoch 23/50
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0634 - acc: 0.9708 - val_loss: 1.7643 - val_acc: 0.8775
# Epoch 24/50
# 30/30 [==============================] - 7s 237ms/step - loss: 0.1577 - acc: 0.9720 - val_loss: 0.6274 - val_acc: 0.9400
# Epoch 25/50
# 30/30 [==============================] - 7s 224ms/step - loss: 0.1771 - acc: 0.9445 - val_loss: 2.0012 - val_acc: 0.8625
# Epoch 26/50
# 30/30 [==============================] - 7s 226ms/step - loss: 0.2983 - acc: 0.9139 - val_loss: 0.0900 - val_acc: 0.9825
# Epoch 27/50
# 30/30 [==============================] - 7s 225ms/step - loss: 0.0902 - acc: 0.9632 - val_loss: 0.1134 - val_acc: 0.9800
# Epoch 28/50
# 30/30 [==============================] - 7s 225ms/step - loss: 0.1992 - acc: 0.9081 - val_loss: 0.7454 - val_acc: 0.9050
# Epoch 29/50
# 30/30 [==============================] - 7s 223ms/step - loss: 0.1314 - acc: 0.9465 - val_loss: 0.8795 - val_acc: 0.9025
# Epoch 30/50
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1685 - acc: 0.9421 - val_loss: 1.3185 - val_acc: 0.8600
# Epoch 31/50
# 30/30 [==============================] - 7s 225ms/step - loss: 0.0556 - acc: 0.9839 - val_loss: 1.0987 - val_acc: 0.8725
# Epoch 32/50
# 30/30 [==============================] - 8s 262ms/step - loss: 0.0614 - acc: 0.9754 - val_loss: 0.2551 - val_acc: 0.9475
# Epoch 33/50
# 30/30 [==============================] - 11s 371ms/step - loss: 0.0802 - acc: 0.9745 - val_loss: 0.0022 - val_acc: 1.0000
# Epoch 34/50
# 30/30 [==============================] - 11s 372ms/step - loss: 0.0481 - acc: 0.9795 - val_loss: 0.0098 - val_acc: 1.0000
# Epoch 35/50
# 30/30 [==============================] - 11s 369ms/step - loss: 0.1679 - acc: 0.9552 - val_loss: 0.0185 - val_acc: 0.9950
# Epoch 36/50
# 30/30 [==============================] - 11s 369ms/step - loss: 0.0109 - acc: 1.0000 - val_loss: 2.7949e-04 - val_acc: 1.0000
# Epoch 37/50
# 30/30 [==============================] - 11s 369ms/step - loss: 0.1509 - acc: 0.9280 - val_loss: 0.0812 - val_acc: 0.9850
# Epoch 38/50
# 30/30 [==============================] - 11s 369ms/step - loss: 0.1068 - acc: 0.9714 - val_loss: 0.0277 - val_acc: 0.9950
# Epoch 39/50
# 30/30 [==============================] - 13s 427ms/step - loss: 0.0865 - acc: 0.9677 - val_loss: 7.2098e-05 - val_acc: 1.0000
# Epoch 40/50
# 30/30 [==============================] - 11s 372ms/step - loss: 0.0103 - acc: 1.0000 - val_loss: 9.9823e-04 - val_acc: 1.0000
# Epoch 41/50
# 30/30 [==============================] - 5s 160ms/step - loss: 0.0311 - acc: 0.9902 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 42/50
# 30/30 [==============================] - 5s 153ms/step - loss: 0.0929 - acc: 0.9717 - val_loss: 6.7850e-04 - val_acc: 1.0000
# Epoch 43/50
# 30/30 [==============================] - 5s 153ms/step - loss: 0.0155 - acc: 0.9952 - val_loss: 0.0014 - val_acc: 1.0000
# Epoch 44/50
# 30/30 [==============================] - 5s 161ms/step - loss: 0.0050 - acc: 0.9995 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 45/50
# 30/30 [==============================] - 6s 199ms/step - loss: 0.0986 - acc: 0.9811 - val_loss: 0.0160 - val_acc: 1.0000
# Epoch 46/50
# 30/30 [==============================] - 18s 589ms/step - loss: 0.0900 - acc: 0.9555 - val_loss: 0.0014 - val_acc: 1.0000
# Epoch 47/50
# 30/30 [==============================] - 43s 1s/step - loss: 0.1090 - acc: 0.9772 - val_loss: 6.4129e-04 - val_acc: 1.0000
# Epoch 48/50
# 30/30 [==============================] - 95s 3s/step - loss: 0.1008 - acc: 0.9638 - val_loss: 0.3454 - val_acc: 0.9525
# Epoch 49/50
# 30/30 [==============================] - 54s 2s/step - loss: 0.1318 - acc: 0.9571 - val_loss: 0.5423 - val_acc: 0.9350
# Epoch 50/50
# 30/30 [==============================] - 56s 2s/step - loss: 0.0467 - acc: 0.9875 - val_loss: 0.2529 - val_acc: 0.9775
